# %% [markdown]
# <a href="https://colab.research.google.com/github/PranaviBurrareddy/PranaviBurrareddy/blob/main/assignment14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-c5d84736ba45> in <cell line: 1>()
# ----> 1 data
#
# NameError: name 'data' is not defined

# %%
dataframe1 = pd.read_csv("/Dataset - salesdata.csv')
# Out:
#   File "<ipython-input-4-2dce4ff3b7f3>", line 1
#     dataframe1 = pd.read_csv("/Dataset - salesdata.csv')
#                              ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
df = pd. read_csv("/Dataset - salesdata.csv")

# %%
df
# Out:
#      OrderDate   Region  Manager   SalesMan          Item  Units Unit_price  \
# 0   01-06-2018     East   Martha  Alexander    Television     95   1,198.00
# 1      1-23-18  Central  Hermann     Shelli  Home Theater     50        500
# 2   02-09-2018  Central  Hermann       Luis    Television     36   1,198.00
# 3      2-26-18  Central  Timothy      David    Cell Phone     27        225
# 4      3-15-18     West  Timothy    Stephen    Television     56   1,198.00
# 5   04-01-2018     East   Martha  Alexander  Home Theater     60        500
# 6      4-18-18  Central   Martha     Steven    Television     75   1,198.00
# 7   05-05-2018  Central  Hermann       Luis    Television     90   1,198.00
# 8      5-22-18     West  Douglas    Michael    Television     32   1,198.00
# 9   06-08-2018     East   Martha  Alexander  Home Theater     60        500
# 10     6-25-18  Central  Hermann      Sigal    Television     90   1,198.00
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      OrderDate   Region  Manager   SalesMan          Item  Units Unit_price  \
# 0   01-06-2018     East   Martha  Alexander    Television     95   1,198.00
# 1      1-23-18  Central  Hermann     Shelli  Home Theater     50        500
# 2   02-09-2018  Central  Hermann       Luis    Television     36   1,198.00
# 3      2-26-18  Central  Timothy      David    Cell Phone     27        225
# 4      3-15-18     West  Timothy    Stephen    Television     56   1,198.00
# 5   04-01-2018     East   Martha  Alexander  Home Theater     60        500
# 6      4-18-18  Central   Martha     Steven    Television     75   1,198.00
# 7   05-05-2018  Central  Hermann       Luis    Television     90   1,198.00
# 8      5-22-18     West  Douglas    Michael    Television     32   1,198.00
# 9   06-08-2018     East   Martha  Alexander  Home Theater     60        500
# 10     6-25-18  Central  Hermann      Sigal    Television     90   1,198.00
# ...

# %%
df_filled = df.fillna(df.mean())
# Out:
# <ipython-input-8-939c007b6345>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_filled = df.fillna(df.mean())

# %%
df.drop(columns="Units")
# Out:
#      OrderDate   Region  Manager   SalesMan          Item Unit_price  \
# 0   01-06-2018     East   Martha  Alexander    Television   1,198.00
# 1      1-23-18  Central  Hermann     Shelli  Home Theater        500
# 2   02-09-2018  Central  Hermann       Luis    Television   1,198.00
# 3      2-26-18  Central  Timothy      David    Cell Phone        225
# 4      3-15-18     West  Timothy    Stephen    Television   1,198.00
# 5   04-01-2018     East   Martha  Alexander  Home Theater        500
# 6      4-18-18  Central   Martha     Steven    Television   1,198.00
# 7   05-05-2018  Central  Hermann       Luis    Television   1,198.00
# 8      5-22-18     West  Douglas    Michael    Television   1,198.00
# 9   06-08-2018     East   Martha  Alexander  Home Theater        500
# 10     6-25-18  Central  Hermann      Sigal    Television   1,198.00
# 11  07-12-2018     East   Martha      Diana  Home Theater        500
# 12     7-29-18     East  Douglas      Karen  Home Theater        500
# ...

# %%
filledDf = df.fillna(0)

# %%
filledDf.head(10)
# Out:
#     OrderDate   Region  Manager   SalesMan          Item  Units Unit_price  \
# 0  01-06-2018     East   Martha  Alexander    Television     95   1,198.00
# 1     1-23-18  Central  Hermann     Shelli  Home Theater     50        500
# 2  02-09-2018  Central  Hermann       Luis    Television     36   1,198.00
# 3     2-26-18  Central  Timothy      David    Cell Phone     27        225
# 4     3-15-18     West  Timothy    Stephen    Television     56   1,198.00
# 5  04-01-2018     East   Martha  Alexander  Home Theater     60        500
# 6     4-18-18  Central   Martha     Steven    Television     75   1,198.00
# 7  05-05-2018  Central  Hermann       Luis    Television     90   1,198.00
# 8     5-22-18     West  Douglas    Michael    Television     32   1,198.00
# 9  06-08-2018     East   Martha  Alexander  Home Theater     60        500
#
#       Sale_amt
# 0  1,13,810.00
# 1    25,000.00
# 2    43,128.00
# 3     6,075.00
# 4    67,088.00
# 5    30,000.00
# 6    89,850.00
# ...

# %%
df.isnull().sum()
# Out:
# OrderDate     0
# Region        0
# Manager       0
# SalesMan      0
# Item          0
# Units         0
# Unit_price    0
# Sale_amt      0
# dtype: int64

# %%
df.mean()
# Out:
# <ipython-input-30-c61f0c8f89b5>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# Units    49.325581
# dtype: float64

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-01827e5d44b9> in <cell line: 1>()
# ----> 1 FFillDf.head(10)
#
# NameError: name 'FFillDf' is not defined

# %%
df2=df.dropna()

# %% [markdown]
# # New Section
